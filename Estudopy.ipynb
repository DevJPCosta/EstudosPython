# %% [markdown]
# <a href="https://colab.research.google.com/github/M0NARCA/EstudosPython/blob/main/Estudopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Claro! Abaixo, fornecerei o código detalhado para cada uma das atividades mencionadas, juntamente com explicações relevantes.
#
# Atividade 1 - Paradigma Científico Centrado em Dados:
#
# python
# Copy code
# def buscar_animes_por_genero(animes, genero):
#     animes_por_genero = []
#     for anime in animes:
#         if anime['genero'] == genero:
#             animes_por_genero.append(anime)
#     return animes_por_genero
#
# animes = [
#     {'nome': 'Naruto', 'genero': 'Ação', 'episodios': 500},
#     {'nome': 'Attack on Titan', 'genero': 'Ação', 'episodios': 75},
#     {'nome': 'One Piece', 'genero': 'Aventura', 'episodios': 1000},
#     {'nome': 'Death Note', 'genero': 'Suspense', 'episodios': 37}
# ]
#
# animes_acao = buscar_animes_por_genero(animes, 'Ação')
# print(animes_acao)
# Explicação: Nesta atividade, criamos uma função chamada buscar_animes_por_genero que recebe como parâmetros uma lista de animes e um gênero. A função percorre a lista de animes e retorna uma nova lista contendo apenas os animes que possuem o gênero especificado.
#
# Em seguida, definimos uma lista de animes com seus respectivos nomes, gêneros e número de episódios. Chamamos a função buscar_animes_por_genero passando a lista de animes e o gênero 'Ação' como argumentos. O resultado é armazenado na variável animes_acao e impresso na tela.
#
# Paradigma Científico Centrado em Dados:
#
# Trata-se de um novo paradigma científico que coloca os dados como o centro do processo de investigação e tomada de decisão.
# Exemplo: Na análise de dados dos seus animes favoritos, você pode buscar animes por gênero, utilizando uma função em Python, como a função buscar_animes_por_genero(), que retorna os animes de um determinado gênero.

# %%
def buscar_animes_por_genero(animes, genero):
    animes_por_genero = []
    for anime in animes:
        if anime['genero'] == genero:
            animes_por_genero.append(anime)
    return animes_por_genero

animes = [
    {'nome': 'Naruto', 'genero': 'Ação', 'episodios': 500},
    {'nome': 'Attack on Titan', 'genero': 'Ação', 'episodios': 75},
    {'nome': 'One Piece', 'genero': 'Aventura', 'episodios': 1000},
    {'nome': 'Death Note', 'genero': 'Suspense', 'episodios': 37}
]

animes_acao = buscar_animes_por_genero(animes, 'Ação')
print(animes_acao)
# Out:
# [{'nome': 'Naruto', 'genero': 'Ação', 'episodios': 500}, {'nome': 'Attack on Titan', 'genero': 'Ação', 'episodios': 75}]

# %% [markdown]
# Explicação: Nesta atividade, utilizamos a biblioteca matplotlib para criar um gráfico de barras que representa a popularidade dos animes. Definimos uma lista de animes e uma lista de valores de popularidade correspondentes a cada anime.
#
# Em seguida, utilizamos o método plt.bar() para criar o gráfico de barras, onde os animes são exibidos no eixo x e a popularidade no eixo y. Utilizamos as funções plt.xlabel(), plt.ylabel() e plt.title() para adicionar rótulos aos eixos e um título ao gráfico.
#
# Por fim, utilizamos o método plt.show() para exibir o gráfico na tela.
# Técnicas para Coleta, Integração, Visualização e Pré-processamento de Dados:
#
# Engloba técnicas para coletar dados, integrá-los, visualizá-los de forma eficiente e prepará-los para análises posteriores.
# Exemplo: Você pode utilizar a biblioteca matplotlib em Python para criar gráficos de barras que representem a popularidade dos seus animes favoritos, como exemplificado na atividade 2.

# %%
import matplotlib.pyplot as plt

animes = ['Naruto', 'Attack on Titan', 'One Piece', 'Death Note']
popularidade = [9, 8, 9.5, 8.5]

plt.bar(animes, popularidade)
plt.xlabel('Animes')
plt.ylabel('Popularidade')
plt.title('Popularidade dos Animes')
plt.show()

# %% [markdown]
# Explicação: Nesta atividade, criamos uma função chamada filtrar_mangas_por_capitulos que recebe como parâmetros uma lista de mangás e um número mínimo de capítulos. A função percorre a lista de mangás e retorna uma nova lista contendo apenas os mangás que possuem mais capítulos do que o número mínimo especificado.
#
# Em seguida, definimos uma lista de mangás com seus respectivos títulos e número de capítulos. Chamamos a função filtrar_mangas_por_capitulos passando a lista de mangás e o número mínimo de capítulos como argumentos. O resultado é armazenado na variável mangas_filtrados e impresso na tela.
# Fundamentos da Engenharia de Dados:
#
# Abrange os princípios e técnicas de manipulação e processamento de dados de forma eficiente e escalável.
# Exemplo: Através de uma função em Python, como a função filtrar_mangas_por_capitulos(), você pode filtrar mangás com base no número mínimo de capítulos que você deseja.

# %%
def filtrar_mangas_por_capitulos(mangas, num_min_capitulos):
    mangas_filtrados = []
    for manga in mangas:
        if manga['capitulos'] > num_min_capitulos:
            mangas_filtrados.append(manga)
    return mangas_filtrados

mangas = [
    {'titulo': 'One Piece', 'capitulos': 1000},
    {'titulo': 'Attack on Titan', 'capitulos': 139},
    {'titulo': 'Berserk', 'capitulos': 364},
    {'titulo': 'Naruto', 'capitulos': 700}
]

mangas_filtrados = filtrar_mangas_por_capitulos(mangas, 200)
print(mangas_filtrados)
# Out:
# [{'titulo': 'One Piece', 'capitulos': 1000}, {'titulo': 'Berserk', 'capitulos': 364}, {'titulo': 'Naruto', 'capitulos': 700}]

# %% [markdown]
# Explicação: Nesta atividade, criamos uma classe chamada Anime que possui atributos como nome, gênero, popularidade e ano de lançamento. No construtor da classe (__init__), definimos os valores iniciais para esses atributos.
#
# Além disso, a classe possui um método chamado recomendar_anime_por_genero que recebe um gênero como parâmetro. O método verifica se o gênero do anime é igual ao gênero especificado e retorna o nome do anime se for verdadeiro, caso contrário, retorna None.
#
# Criamos objetos da classe Anime com diferentes atributos para representar os animes. Em seguida, chamamos o método recomendar_anime_por_genero do objeto anime2 passando o gênero 'Ação' como argumento. O resultado é armazenado na variável recomendacao e impresso na tela
# Engenharia de Atributos e Criação de Modelos de Machine Learning:
#
# Envolve a criação e seleção de atributos relevantes para alimentar modelos de machine learning, a fim de obter resultados mais precisos e significativos.
# Exemplo: Você pode criar uma classe em Python, como a classe Anime, que possui atributos como gênero, popularidade e ano de lançamento, e implementar um método que recomenda animes com base no gênero.

# %%
class Anime:
    def __init__(self, nome, genero, popularidade, ano_lancamento):
        self.nome = nome
        self.genero = genero
        self.popularidade = popularidade
        self.ano_lancamento = ano_lancamento

    def recomendar_anime_por_genero(self, genero):
        if self.genero == genero:
            return self.nome
        else:
            return None

anime1 = Anime('Naruto', 'Ação', 9, 2002)
anime2 = Anime('Attack on Titan', 'Ação', 8, 2013)
anime3 = Anime('One Piece', 'Aventura', 9.5, 1999)
anime4 = Anime('Death Note', 'Suspense', 8.5, 2006)

recomendacao = anime2.recomendar_anime_por_genero('Ação')
print(recomendacao)
# Out:
# Attack on Titan

# %% [markdown]
# Explicação: Nesta atividade, utilizamos a biblioteca matplotlib para criar um gráfico de pizza que representa a distribuição dos gêneros dos seus animes favoritos. Definimos uma lista de gêneros de animes e uma lista contendo a quantidade de animes em cada gênero.
#
# Utilizamos o método plt.pie() para criar o gráfico de pizza, passando a lista quantidade como dados, a lista generos como rótulos dos setores e autopct='%1.1f%%' para exibir as porcentagens de cada gênero. Utilizamos a função plt.title() para adicionar um título ao gráfico.
#
# Por fim, utilizamos o método plt.show() para exibir o gráfico na tela.
# Visualização de Dados e Comunicação de Resultados:
#
# Compreende a representação visual dos dados de forma clara e eficaz, para comunicar insights e resultados de análises.
# Exemplo: Utilizando a biblioteca matplotlib, é possível criar gráficos de pizza que mostram a distribuição de gêneros dos seus animes favoritos, como exemplificado na atividade 5.

# %%
import matplotlib.pyplot as plt

generos = ['Ação', 'Comédia', 'Drama', 'Suspense']
quantidade = [8, 5, 3, 4]

plt.pie(quantidade, labels=generos, autopct='%1.1f%%')
plt.title('Distribuição de Gêneros de Animes')
plt.show()
